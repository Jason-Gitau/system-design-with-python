# %%
pip install diagrams
# Out:
# Collecting diagrams
#   Downloading diagrams-0.25.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting graphviz<0.21.0,>=0.13.2 (from diagrams)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2<4.0,>=2.10 in /usr/local/lib/python3.12/dist-packages (from diagrams) (3.1.6)
# Collecting pre-commit<5,>=4.0.1 (from diagrams)
#   Downloading pre_commit-4.5.1-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0,>=2.10->diagrams) (3.0.3)
# Collecting cfgv>=2.0.0 (from pre-commit<5,>=4.0.1->diagrams)
#   Downloading cfgv-3.5.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting identify>=1.0.0 (from pre-commit<5,>=4.0.1->diagrams)
#   Downloading identify-2.6.18-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit<5,>=4.0.1->diagrams)
#   Downloading nodeenv-1.10.0-py2.py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit<5,>=4.0.1->diagrams) (6.0.3)
# Collecting virtualenv>=20.10.0 (from pre-commit<5,>=4.0.1->diagrams)
#   Downloading virtualenv-21.2.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.24.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (3.25.2)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (4.9.4)
# Collecting python-discovery>=1 (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams)
#   Downloading python_discovery-1.2.1-py3-none-any.whl.metadata (5.4 kB)
# Downloading diagrams-0.25.1-py3-none-any.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 45.3 MB/s eta 0:00:00
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 3.6 MB/s eta 0:00:00
# Downloading pre_commit-4.5.1-py2.py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 18.1 MB/s eta 0:00:00
# Downloading cfgv-3.5.0-py2.py3-none-any.whl (7.4 kB)
# Downloading identify-2.6.18-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 7.8 MB/s eta 0:00:00
# Downloading nodeenv-1.10.0-py2.py3-none-any.whl (23 kB)
# Downloading virtualenv-21.2.0-py3-none-any.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 96.0 MB/s eta 0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 31.5 MB/s eta 0:00:00
# Downloading python_discovery-1.2.1-py3-none-any.whl (31 kB)
# Installing collected packages: distlib, python-discovery, nodeenv, identify, graphviz, cfgv, virtualenv, pre-commit, diagrams
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.21
#     Uninstalling graphviz-0.21:
#       Successfully uninstalled graphviz-0.21
# Successfully installed cfgv-3.5.0 diagrams-0.25.1 distlib-0.4.0 graphviz-0.20.3 identify-2.6.18 nodeenv-1.10.0 pre-commit-4.5.1 python-discovery-1.2.1 virtualenv-21.2.0

# %%
import os
os.listdir(".")  # lists all files in current directory
# Out:
# ['.config', 'simple_payment_backend_system.png', 'sample_data']

# %%
from diagrams import Diagram, Cluster
from diagrams.aws.compute import ECS
from diagrams.aws.database import RDS
from diagrams.aws.integration import SQS
from diagrams.aws.network import ELB
from diagrams.aws.security import Cognito
from diagrams.onprem.client import User
from diagrams.onprem.compute import Server

with Diagram("Simple Payment Backend System", show=False):
    user = User("Client App")
    api_gateway = ELB("API Gateway")
    auth = Cognito("Auth Service")

    with Cluster("Payment Services"):
        payment_service = ECS("Payment API")
        queue = SQS("Payment Queue")
        worker = ECS("Payment Worker")

    db = RDS("Transactions DB")
    payment_provider = Server("External Payment Provider")

    user >> api_gateway
    api_gateway >> auth
    api_gateway >> payment_service
    payment_service >> queue
    queue >> worker
    worker >> payment_provider
    worker >> db
    payment_service >> db

# ---- Add these lines to display in Colab ----
from IPython.display import Image, display
display(Image("simple_payment_backend_system.png"))

# %%
from IPython.display import Image, display  # ✅ moved to top

from diagrams import Diagram, Cluster
from diagrams.onprem.client import User
from diagrams.onprem.compute import Server
from diagrams.onprem.network import Nginx
from diagrams.onprem.database import PostgreSQL

from diagrams.aws.compute import ECS
from diagrams.aws.integration import SQS

with Diagram(
    "MPesa System Architecture (USSD + API Flow)",
    show=False,
    filename="mpesa_architecture"  # ✅ explicit, predictable filename
):
    # Users
    mobile_user = User("Mobile User (*334#)")
    app_user = User("App / Website User")

    # --- USSD FLOW ---
    with Cluster("USSD Channel"):
        ussd_gateway = Server("USSD Gateway")
        telecom_core = Server("Safaricom Core Network")

    # --- API FLOW ---
    with Cluster("Daraja API Gateway"):
        api_gateway = Nginx("API Gateway")
        auth_service = Server("OAuth Service")

    # --- MPesa Core ---
    with Cluster("MPesa Core System"):
        payment_processor = ECS("Payment Processor")
        transaction_queue = SQS("Transaction Queue")
        worker = ECS("Processing Worker")
        mpesa_db = PostgreSQL("MPesa DB")

    # --- External Systems ---
    with Cluster("External Integrations"):
        business_server = Server("Business Backend (Your Bot/API)")
        callback_listener = Server("Callback URL")

    # USSD Flow
    mobile_user >> ussd_gateway >> telecom_core >> payment_processor

    # API Flow
    app_user >> api_gateway >> auth_service >> payment_processor

    # Internal Processing
    payment_processor >> transaction_queue >> worker
    worker >> mpesa_db

    # External API Integration (Daraja)
    payment_processor >> business_server
    worker >> callback_listener

    # Persistence
    payment_processor >> mpesa_db

# ✅ outside the with block
display(Image("mpesa_architecture.png"))
